# %% [markdown]
# Estrutura de repetição: for
#
# - Funcionamento:

# %%
#for i in range(n):
#   repetir código n vezes

# %%
for i in range(5):
    print(i, end=' ')
# Out:
# 0 1 2 3 4

# %%
#Imagine que você está construindo uma automação para enviar todo dia por e-mail um resumo da produção de uma fábrica. Construa um código que exiba a quantidade produzida de cada produto nesse 'e-mail'

produtos = ['coca', 'pepsi', 'guarana', 'sprite', 'fanta']
producao = [15000, 12000, 13000, 5000, 250]

for i in range(len(produtos)):
    print(f'{producao[i]} unidades produzidas de {produtos[i]}')
# Out:
# 15000 unidades produzidas de coca
# 12000 unidades produzidas de pepsi
# 13000 unidades produzidas de guarana
# 5000 unidades produzidas de sprite
# 250 unidades produzidas de fanta

# %%
#For 'each'
#Estrutura:
#O for no Python consegue percorrer uma lista e a cada 'loop' retoenar o valor do item
#for i in range(5):
    #print(i)
#range(5) é na verdade uma lista do tipo: [0, 1, 2, 3, 4]

# %%
#Usando para listas:
#for item in lista:
#   print(item)

#ou então para string:
#for ch in texto:
#   print(ch)

# %%
texto = 'lira@gmail.com'

for i in range(5):
    print(produtos[i])
# Out:
# coca
# pepsi
# guarana
# sprite
# fanta

# %%
for produto in produtos:
    print(produto)
# Out:
# coca
# pepsi
# guarana
# sprite
# fanta

# %%
for ch in texto:
    print(ch, end=' ')
# Out:
# l i r a @ g m a i l . c o m

# %%
#For + if
#Estrutura:
#for item inlista:
#   if condicao:
#       faça alguma coisa
#   else:
#       outra coisa


#Digamos que a gente esteja analisando a meta de vendas de vários funcionários de uma empresa. A meta de vendas é de 1000 reais em 1 dia.
#Temos uma lista com as vendas de todos os funcionários e quero calcular qual o % de pessoas que bateram a meta.

# %%
vendas = [1200, 300, 800, 1500, 1900, 2750, 400, 20, 23, 70, 90, 80, 1100, 999, 900, 880, 870, 50, 1111, 120, 300, 450, 800]
meta = 1000
qtd_bateu_meta = 0

for venda in vendas:
    if venda >= meta:
        #print(venda, end=' ')
        qtd_bateu_meta += 1

print(f'O percentual de funcionários que bateram a meta foi de {(qtd_bateu_meta / len(vendas)) * 100:.1f}%')
# Out:
# O percentual de funcionários que bateram a meta foi de 26.1%

# %% [markdown]
# ###Enumerate
#
# - Estrutura:
#     - O enumerate permite que você percorra uma lista e ao mesmo tempo tenha em uma variável o índice daquele item

# %%
#for item in lista:
#   resto do código

#for i, item in enumerate(lista):
#   resto do código

# %%
funcionarios = ['Maria', 'José', 'Antônio', 'João', 'Francisco', 'Ana', 'Luiz', 'Paulo', 'Carlos', 'Manoel', 'Pedro', 'Francisca', 'Marcos', 'Raimundo', 'Sebastião', 'Antônia', 'Marcelo', 'Jorge', 'Marcia', 'Geraldo', 'Adriana', 'Sandra', 'Luis']

for i, funcionario in enumerate(funcionarios):
    print(f'O indice {i} é o funcionário {funcionario}')
# Out:
# O indice 0 é o funcionário Maria
# O indice 1 é o funcionário José
# O indice 2 é o funcionário Antônio
# O indice 3 é o funcionário João
# O indice 4 é o funcionário Francisco
# O indice 5 é o funcionário Ana
# O indice 6 é o funcionário Luiz
# O indice 7 é o funcionário Paulo
# O indice 8 é o funcionário Carlos
# O indice 9 é o funcionário Manoel
# O indice 10 é o funcionário Pedro
# O indice 11 é o funcionário Francisca
# O indice 12 é o funcionário Marcos
# O indice 13 é o funcionário Raimundo
# O indice 14 é o funcionário Sebastião
# O indice 15 é o funcionário Antônia
# O indice 16 é o funcionário Marcelo
# O indice 17 é o funcionário Jorge
# O indice 18 é o funcionário Marcia
# O indice 19 é o funcionário Geraldo
# O indice 20 é o funcionário Adriana
# O indice 21 é o funcionário Sandra
# O indice 22 é o funcionário Luis

# %%
#Exemplo prático
#Vamos pegar um exemplo denível mínimo de estoque. Em uma fábrica você tem vários produtos e não pode deixar que os produtos fiquem em falta. Para isso, foi definidouma quantidade mínima de estoque que os produtos precisam ter:

#Identifique quais produtos estão abaixo do nível mínimo de estoque:

estoque = [1200, 300, 800, 1500, 1900, 2750, 400, 20, 23, 70, 90, 80, 1100, 999, 900, 880, 870, 50, 1111, 120, 300, 450, 900]
produtos = ['coca', 'pepsi', 'guarana', 'skol', 'brahma', 'água', 'del valle', 'dolly', 'red bull', 'cachaça', 'vinho tinto']
nivel_minimo = 50

print(len(estoque))
print(len(produtos))
# Out:
# 23
# 11

# %%
for i,qtde in enumerate(estoque):
    if qtde < nivel_minimo:
        print(f'{produtos[i]} está abaixo do nível mínimo. Temos apenas {qtde} unidades')
# Out:
# dolly está abaixo do nível mínimo. Temos apenas 20 unidades
# red bull está abaixo do nível mínimo. Temos apenas 23 unidades

# %%
produtos = ['iphone', 'ipad', 'airpod','macbook']
precos = [7000, 10000, 2500, 14000]

# %%
#For item in lista
#preço com imposto
for preco in precos:
    print(preco * 1.1)
# Out:
# 7700.000000000001
# 11000.0
# 2750.0
# 15400.000000000002

# %%
#For in range
#preço de cada produto
for i in range(len(precos)):
    produto = produtos[i]
    preco = precos[i]
    print(produto, preco)
# Out:
# iphone 7000
# ipad 10000
# airpod 2500
# macbook 14000

# %%
#For item in lista com enumerate
#preço de cada produto com imposto
for i, preco in enumerate(precos):
    preco *= 1.1
    produto = produtos[i]
    print(produto, preco)
# Out:
# iphone 7700.000000000001
# ipad 11000.0
# airpod 2750.0
# macbook 15400.000000000002

# %% [markdown]
# ###For dentro de for
#
# Quando temos listas dentro de listas, às vezes precisamos fazer um 'for dentro de for'
#
# Vamos pegar um exemplo de nível mínimo de estoque. Em uma fábrica você tem vários produtos e não pode deixar que os produtos fiquem em falta. Para isso, foi definido uma quantidade mínima de estoque que os produtos precisam ter:
#
# Indique quais fábricas tem algum produto abaixo do nível de estoque
#
# Agora ao invés de analisar o estoque de apenas 1 fábrica, vamos analisar o estoque de várias fábricas

# %%
#for item in lista:
#   for item2 in lista2:
#       código aqui

# %%
estoque = [
        [294, 125, 269, 208, 783, 852, 259, 371, 47, 102, 386, 87, 685, 686, 697, 941, 163, 631, 7, 714, 218, 670, 453],
        [648, 816, 310, 555, 992, 643, 226, 319, 501, 23, 239, 42, 372, 441, 126, 645, 927, 911, 761, 445, 974, 2, 549],
        [832, 683, 784, 449, 977, 705, 198, 937, 729, 327, 339, 10, 975, 310, 95, 689, 137, 795, 211, 538, 933, 751, 522],
        [837, 168, 570, 397, 53, 297, 966, 714, 72, 737, 259, 629, 625, 469, 922, 305, 782, 243, 841, 848, 372, 621, 362],
        [429, 242, 53, 985, 406, 186, 198, 50, 501, 870, 781, 632, 781, 105, 644, 509, 401, 88, 961, 765, 422, 340, 654],
    ]
fabricas = ['Lira Manufacturing', 'Fábrica Hashtag', 'Python Manufaturas', 'Produções e Cia', 'Manufatura e Cia']
nivel_minimo = 50
fabricas_abaixo_nivel = []

# %%
for i, lista in enumerate(estoque):
    #se dentro daquela lista tem alguém abaixo do estoque
    for qtde in lista:
        if qtde < nivel_minimo:
            if fabricas[i] in fabricas_abaixo_nivel:
                pass
            else:
                fabricas_abaixo_nivel.append(fabricas[i])
                
print(fabricas_abaixo_nivel)
# Out:
# ['Lira Manufacturing', 'Fábrica Hashtag', 'Python Manufaturas']

# %% [markdown]
# ###Formas de interromper um for
#
# - 2 opções:
#     - break -> Interrompe e finaliza o for
#     - continue -> Interrompe e vai para o próximo item do for

# %%
#Caso 1: Se todas as vendas forem acima da meta, a loja ganha bônus
vendas = [100, 150, 1500, 2000, 120]
meta = 110

for venda in vendas:
    if venda < meta:
        print('A loja não ganhou bônus')
        break
    print(venda)
# Out:
# A loja não ganhou bônus

# %%
#caso 2: Exiba quem bateu a meta
vendedores = ['João', 'Julia', 'Ana', 'José', 'Maria']
meta = 130

for i,venda in enumerate(vendas):
    if venda < meta:
        continue
    print(f'{vendedores[i]} vendeu {venda} unidades e bateu a meta de {meta} unidades')
# Out:
# Julia vendeu 150 unidades e bateu a meta de 130 unidades
# Ana vendeu 1500 unidades e bateu a meta de 130 unidades
# José vendeu 2000 unidades e bateu a meta de 130 unidades

# %% [markdown]
# ###Estrutura while:
#
# Funcionamento:
# - Usamos o while quando queremos repetir um código de forma indeterminada até uma condição se tornar verdadeira/falsa
# - A lógica é: enquanto a condição for verdadeira, o while executa o código. Assim que ela terminar de ser verdadeira, o código 'sai' do while

# %%
#while condição:
#   repete esse código

# %% [markdown]
# - Exemplo: quando criamos automações na internet
# - Exemplo2: crie um programa que funcione como o registro de vendas de uma empresa
#
# Nele, a pessoa deve inserir o nome do produto e o produto deve ser adicionado na lista de vendas. Enquanto o usuário não encerrar o programa, significa que ele está registrando novos produtos, então o programa deve permitir a entrada de quantos produtos o usuário quiser

# %%
venda = input('Registre um produto. Para cancelar o resgistro de um novo produto, basta apertar enter com a caixa vazia')
vendas = []

while venda != '':
    vendas.append(venda)
    venda = input('Registre um produto. Para cancelar o resgistro de um novo produto, basta apertar enter com a caixa vazia')


print(f'Registro finalizado. As vendas cadastradas foram: {vendas}')
# Out:
# Registro finalizado. As vendas cadastradas foram: ['arroz', 'feijão', 'frango', 'macarrão']

# %% [markdown]
# ###Cuidado com o while -> Loop infinito
#
# Sempre que for usar o comando while,lembre-se de ter certeza que o programa vai terminar em algum momento

# %%
#Exemplo: Digamos que temos uma lista de vendedores e as quantidades vendidas e queremos identificar todos os vendedores que bateram a mea de 50 vendas

vendas = [941, 852, 783, 714, 697, 686, 685, 670, 631, 453, 386, 371, 294, 269, 259, 218, 208, 163, 125, 102, 87, 47, 7]
vendedores = ['Maria', 'José', 'Antônio', 'João', 'Francisco', 'Ana', 'Luiz', 'Paulo', 'Carlos', 'Manoel', 'Pedro', 'Francisca', 'Marcos', 'Raimundo', 'Sebastião', 'Antônia', 'Marcelo', 'Jorge', 'Márcia', 'Geraldo', 'Adriana', 'Sandra', 'Luis']
meta = 50

i = 0
while vendas[i] > meta:
    print(f'{vendedores[i]} bateu a meta. Vendas: {vendas[i]}')
    i += 1
# Out:
# Maria bateu a meta. Vendas: 941
# José bateu a meta. Vendas: 852
# Antônio bateu a meta. Vendas: 783
# João bateu a meta. Vendas: 714
# Francisco bateu a meta. Vendas: 697
# Ana bateu a meta. Vendas: 686
# Luiz bateu a meta. Vendas: 685
# Paulo bateu a meta. Vendas: 670
# Carlos bateu a meta. Vendas: 631
# Manoel bateu a meta. Vendas: 453
# Pedro bateu a meta. Vendas: 386
# Francisca bateu a meta. Vendas: 371
# Marcos bateu a meta. Vendas: 294
# Raimundo bateu a meta. Vendas: 269
# Sebastião bateu a meta. Vendas: 259
# Antônia bateu a meta. Vendas: 218
# Marcelo bateu a meta. Vendas: 208
# Jorge bateu a meta. Vendas: 163
# Márcia bateu a meta. Vendas: 125
# Geraldo bateu a meta. Vendas: 102
# Adriana bateu a meta. Vendas: 87
