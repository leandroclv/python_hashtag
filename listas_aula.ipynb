# %% [markdown]
# ###Listas em Python
#
# ####EStrutura:
#
# lista = [valor, valor,valor, ...]
#
# - Lista é um dos objetivos mais importantes de Python,por isso vamos trabalhar bastante neles
# - Quando importamos uma base de dados para o Python, normalmente ele é lido como uma 'lista' ou como alguma 'variação de lista'
# - Listas em Python foram feitas para serem homogêneas, apesar de aceitarem valores heterogêneos
# - Exemplos de lista:

# %%
#Listas de produtos de uma loja:
produtos = ['tv', 'celular', 'mouse', 'teclado', 'tablet']

#nome = laptop
#produtos = ['tv', 'celular', 'mouse', 'teclado', 'tablet', nome]
#print(produtos) -> ['tv', 'celular', 'mouse', 'teclado', 'tablet', 'laptop']

#Lista de unidades vendidas de cada produto da loja:
vendas = [1000, 1500, 350, 270, 900]

# %%
#Lista[i] -> é o valor de índice i da lista
#Obs: Lembre que no python o índice começa em 0, então o primeiro item de uma lista é o item lista[0]

#Para substituir um valor de uma lista você pode fazer:
#lista[i] = novo_valor

# %%
print(f'Vendas do produto {produtos[0]} foram de {vendas[0]} unidades')
# Out:
# Vendas do produto tv foram de 1000 unidades

# %%
vendas[0] = 300
print(f'Vendas do produto {produtos[0]} foram de {vendas[0]} unidades')
# Out:
# Vendas do produto tv foram de 300 unidades

# %%
texto = 'lira@gmail.com'
print(texto)
# Out:
# lira@gmail.com

# %%
#texto[1] = 'a' #string não é multável
#print(texto) -> 'str' object does not support item assignment
novo_texto = texto.replace('i', 'a') #escrevendo uma nova variável
print(novo_texto)
texto = texto.replace('i', 'a') #sobreescrevendo a variável texto
print(texto)
# Out:
# lara@gmaal.com
# lara@gmaal.com

# %% [markdown]
# ###Como descobrir o índice de um item de uma lista
#
# i = lista.index('item')

# %%
products = ['tv', 'celular', 'tablet', 'mouse', 'teclado', 'geladeira', 'forno']
estoque = [100, 150, 100, 120, 70, 180, 80]

# %%
i = products.index('geladeira')
qtde_estoque = estoque[i]
print(f'Quantidade em estoque de geladeira é de :{qtde_estoque}')
# Out:
# Quantidade em estoque de geladeira é de :180

# %%
#Crie um programa para fazer uma consulta de estoque. O usuário do programa deve inserir o nome do produto e, caso ele não exista na lista, ele é avisado. Caso exista, o programa deve dizer a quantidade de unidades em estoque do produto.

produto = input('Insisra o nome do produto: ').lower()
if produto in products:
    item = products.index(produto)
    print(f'O produto {produto} possui {estoque[item]} unidades')
else:
    print(f'O produto {produto} não está na lista de produtos da loja')
# Out:
# O produto  não está na lista de produtos da loja

# %% [markdown]
# ###Adicionar e remover itens de uma lista

# %%
#Adicionar:
#lista.append(item)

#Remover:
#item_removido = lista.pop(indice)
#lista.remove(item)

#Digamos que você está construindo o controle de produtos da Apple. E a Apple lançou o IPhone 11 e irá tirar dos seus estoques o IPhoneX

# %%
product = ['apple tv', 'mac', 'iphone x', 'Ipad', 'apple watch', 'mac book', 'airpods']
product[2] = 'iphone 11'

# %%
print(product)
# Out:
# ['apple tv', 'mac', 'iphone 11', 'Ipad', 'apple watch', 'mac book', 'airpods']

# %%
product.append('iphone 22')
print(product)
# Out:
# ['apple tv', 'mac', 'iphone 11', 'Ipad', 'apple watch', 'mac book', 'airpods', 'iphone 22']

# %%
product.remove('mac book')
print(product)
# Out:
# ['apple tv', 'mac', 'iphone 11', 'Ipad', 'apple watch', 'airpods', 'iphone 22']

# %%
item_removido = product.pop(1)
print(item_removido)
print(product)
# Out:
# mac
# ['apple tv', 'iphone 11', 'Ipad', 'apple watch', 'airpods', 'iphone 22']

# %% [markdown]
# ###Existem 2 formas de tratar um erro:
#
# - 1.Criar um if para evitar que ele aconteça
# - 2.Esperar que ele possa acontecer e tratar caso o erro aconteça

# %%
#try:
    #tentar fazer
#except:
    #caso dê errado

# %%
try:
    product.remove('iphone11')
    print(product)
except:
    print('não existe na lista de produtos') #pode colocar 'pass' para não fazer nada
# Out:
# não existe na lista de produtos

# %% [markdown]
# ###Algumas funções Básicas de lista
#
# - Tamanho da lista -> tamanho = len(lista)
# - Maior ou menor valor -> maior = max(lista) e menor = min(lista)

# %%
tamanho = len(product)
tamanho
# Out:
# 6

# %%
vendas = [1000, 1500, 15000, 270, 900, 100, 1200]

#Qual o item mais vendidos?
mais_vendidos = max(vendas)

#Qual o item menos vendidos?
menos_vendidos = min(vendas)

print(f'O produto mais vendido foi {mais_vendidos} e o menor valor foi de {menos_vendidos}')
# Out:
# O produto mais vendido foi 15000 e o menor valor foi de 100

# %%
i = vendas.index(mais_vendidos)

produto_mais_vendidos = product[i] 
produto_mais_vendidos
# Out:
# 'Ipad'

# %%
i = vendas.index(menos_vendidos)
produto_menos_vendido = product[i]
produto_menos_vendido
# Out:
# 'iphone 22'

# %% [markdown]
# ###Juntar listas, ordenar e cuidados especiais
#
# - 2 formas:
#     - lista1.extend(lista2)
#     - lista_nova = lista1 + lista2
#
# OBS: o método append() não junta listas, mas adiciona um valor no final da lista
# OBS2: [1] + [2] não é a mesma coisa que 1 + 2, então cuidado sempre com o formato dos valores na hora de fazer operações
#
# - Ordenar listas
#     - lista.sort()

# %%
product = ['apple tv', 'mac', 'iphone x', 'iphone 11' 'Ipad', 'apple watch', 'mac book', 'airpods']
novos_produtos = ['iphone 12', 'ioculos']

# %%
product.extend(novos_produtos)
product

#Caso você não queira modificar a lista original -> todos_produtos = product + novos_produtos
# Out:
# ['apple tv',
#  'mac',
#  'iphone x',
#  'iphone 11Ipad',
#  'apple watch',
#  'mac book',
#  'airpods',
#  'iphone 12',
#  'ioculos']

# %%
vendas_iphonex= [15000]
vendas_iphone11= [20000]

total_iphone = vendas[2] + vendas[3]
print(total_iphone)

total_iphone_itens = vendas_iphonex + vendas_iphone11
print(total_iphone_itens)
# Out:
# 15270
# [15000, 20000]

# %%
print(product)
product.sort()
print(product)
# Out:
# ['apple tv', 'mac', 'iphone x', 'iphone 11Ipad', 'apple watch', 'mac book', 'airpods', 'iphone 12', 'ioculos']
# ['airpods', 'apple tv', 'apple watch', 'ioculos', 'iphone 11Ipad', 'iphone 12', 'iphone x', 'mac', 'mac book']

# %%
#caso queira que a ordem seja trocada 
product.sort(reverse=True)
print(product)
# Out:
# ['mac book', 'mac', 'iphone x', 'iphone 12', 'iphone 11Ipad', 'ioculos', 'apple watch', 'apple tv', 'airpods']

# %% [markdown]
# ###Print de listass
#
# - 2 opções:
#     - print 'normal'
#     - método join -> texto.join(lista)
#
# lembrando do método split de strings: lista = texto.split(separador)

# %%
product = ['apple tv', 'mac', 'iphone x', 'Ipad', 'apple watch', 'mac book', 'airpods']
print(product)
# Out:
# ['apple tv', 'mac', 'iphone x', 'Ipad', 'apple watch', 'mac book', 'airpods']

# %%
print(', '.join(product))
print('; '.join(product))
print('\n'.join(product))
# Out:
# apple tv, mac, iphone x, Ipad, apple watch, mac book, airpods
# apple tv; mac; iphone x; Ipad; apple watch; mac book; airpods
# apple tv
# mac
# iphone x
# Ipad
# apple watch
# mac book
# airpods

# %%
produto = 'apple tv, mac, iphone x, Ipad, apple watch, mac book, airpods'
lista = produto.split(', ')
print(lista)
# Out:
# ['apple tv', 'mac', 'iphone x', 'Ipad', 'apple watch', 'mac book', 'airpods']

# %% [markdown]
# ###Alterações 'incrementais' de variáveis
#
# - Estrutura:
#     - Variável = variável + outro valor
#
# - Ou então
#     - variável += outro_valor

# %%
#Vamos adiconar às variáveis criadas o Produto IPad, 500 vendas
lista = ['mac', 'iphone']
vendas = [100, 200]

lista = lista + ['Ipad']
lista
# Out:
# ['mac', 'iphone', 'Ipad']

# %%
soma_vendas = 300
soma_vendas += 500
soma_vendas
# Out:
# 800

# %%
email = f'Esse mês vendemos um total de {soma_vendas} produtos, sendo:\n{vendas[0]} unidades de {lista[0]}\n{vendas[1]} unidades de {lista[1]}'
print(email)

email += f'\n{500} unidades do Ipad'
print(email)
# Out:
# Esse mês vendemos um total de 800 produtos, sendo:
# 100 unidades de mac
# 200 unidades de iphone
# Esse mês vendemos um total de 800 produtos, sendo:
# 100 unidades de mac
# 200 unidades de iphone
# 500 unidades do Ipad

# %% [markdown]
# ###Copiar e 'igualdade' de listas
#
# - Estrutura:
#      - Quando fazemos:
#
#      lista2 = lista1
#      -> não estamos criando uma lista nova, mas estamos atribuindo outra variável à mesma lista
#
#      - Se quisermos copiar lista devemos fazer
#      -> lista2 = lista1.copy(),
#      ou então
#      -> lista2 = lista1[:]

# %%
lista = ['ipad', 'iphone x', 'apple tv']
lista2 = lista

lista[1] = 'iphone 11'

print(lista)
print(lista2)
# Out:
# ['ipad', 'iphone 11', 'apple tv']
# ['ipad', 'iphone 11', 'apple tv']

# %%
lista = ['ipad', 'iphone x', 'apple tv']
lista2 = lista.copy()

lista[1] = 'iphone 11'
print(lista)
print(lista2)
# Out:
# ['ipad', 'iphone 11', 'apple tv']
# ['ipad', 'iphone x', 'apple tv']

# %% [markdown]
# ###Listas de listas
#
# - Estrutura:
#
#     - Cada item de uma lista pode ser qualquer tipo de variável. Inclusive uma lista
#     - Quando dentro de uma lista teremos cadaitem como sendo uma outra lista. Teremos uma 'residente list', ou seja, uma lista de listas
#     - Todas as regras de lista e tudo que vimos até agora funciona exatamente igual, mas vamos ver como isso funciona na prática

# %%
vendedores = ['Lira', 'João', 'Diego', 'Alon']
produtos = ['ipod', 'iphone']
vendas = [[100, 200], [300, 500], [50, 1000], [900, 10]]

# %%
#Quanto João vendeu de iPad?
#Quanto Diego vendeu de iPhone?
#Qual o total de vendas de iPhone?
