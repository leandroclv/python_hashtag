# %% [markdown]
# ## Contagem regressiva
#
# Um evento especial está programado para começar em 10 segundos. Crie uma contagem regressiva que começa em 10 e vai até 0, com uma pausa de um segundo entre cada número.

# %%
import time

for i in range(10):
    print(f"Faltam {10 - i} segundos para começar")
    time.sleep(1)

print("Começou")
# Out:
# Faltam 10 segundos para começar
# Faltam 9 segundos para começar
# Faltam 8 segundos para começar
# Faltam 7 segundos para começar
# Faltam 6 segundos para começar
# Faltam 5 segundos para começar
# Faltam 4 segundos para começar
# Faltam 3 segundos para começar
# Faltam 2 segundos para começar
# Faltam 1 segundos para começar
# Começou

# %% [markdown]
# ## Formatação de tempo
#
# Uma empresa quer exibir a data e a hora atual em seu site no formato "Dia da semana, dia de mês de ano, horas:minutos". Crie um script Python que mostra a data e a hora atuais neste formato.

# %%
import time
import locale

locale.setlocale(locale.LC_TIME, "pt_BR")

data_atual = time.localtime()
data_texto = time.strftime("%A, %d de %B de %Y, %H:%M" , data_atual)

print(data_texto.title())
# Out:
# Quinta-Feira, 05 De Fevereiro De 2026, 16:23

# %% [markdown]
# ## Tempo de execução
#
# Quanto tempo o código abaixo vai demorar para executar? Vamos gerar um número para cada um dos funcionários de uma empresa e colocar em uma lista para sortear o funcionário vencedor de um prêmio especial de uma viagem de fim de ano. Quanto tempo seu código demora para criar essa lista de números a serem sorteados?

# %%
import time

tempo_inicial = time.time()

sorteio_funcionarios = []
qtde_funcionarios = 100000000
for i in range(qtde_funcionarios):
    num_funcionario = i
    sorteio_funcionarios.append(i)

tempo_final = time.time()

print(f"Demorou {tempo_final - tempo_inicial} segundos para rodar o código")
# Out:
# Demorou 12.64013671875 segundos para rodar o código

# %% [markdown]
# ## Bases de dados mal formatadas
#
# Bases de dados formatadas de forma incorreta é uma das coisas mais comuns em projetos de análise de dados. Sua tarefa é conseguir extrair a data no formato correto de 2 listas de datas diferentes, para podermos futuramente analisar essas datas.

# %%
import time
import locale

locale.setlocale(locale.LC_TIME, "pt_BR")

lista_datas1 = [
    "15 de julho de 2026",
    "22 de agosto de 2026",
    "10 de outubro de 2026",
    "30 de dezembro de 2026",
    "14 de janeiro de 2027",
    "05 de março de 2027",
    "19 de maio de 2027",
    "07 de setembro de 2027",
    "12 de novembro de 2027",
    "25 de dezembro de 2027",
    "02 de fevereiro de 2028",
    "18 de abril de 2028",
    "31 de julho de 2028",
    "11 de outubro de 2028",
    "20 de dezembro de 2028"
]
lista_datas2 = [
    "07-14-2026",
    "09-05-2026",
    "11-20-2026",
    "01-12-2027",
    "03-28-2027",
    "06-15-2027",
    "08-02-2027",
    "10-31-2027",
    "02-14-2028",
    "05-22-2028",
    "09-09-2028",
    "12-25-2028",
    "04-01-2029",
    "07-19-2029",
    "11-11-2029"
]

lista_datas_formatadas = []
for data in lista_datas1:
    data_formatada = time.strptime(data, "%d de %B de %Y")
    lista_datas_formatadas.append(data_formatada)

for data in lista_datas2:
    data_formatada = time.strptime(data, "%m-%d-%Y")
    lista_datas_formatadas.append(data_formatada)


print(lista_datas_formatadas)
print(len(lista_datas_formatadas))
# Out:
# [time.struct_time(tm_year=2026, tm_mon=7, tm_mday=15, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=2, tm_yday=196, tm_isdst=-1), time.struct_time(tm_year=2026, tm_mon=8, tm_mday=22, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=5, tm_yday=234, tm_isdst=-1), time.struct_time(tm_year=2026, tm_mon=10, tm_mday=10, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=5, tm_yday=283, tm_isdst=-1), time.struct_time(tm_year=2026, tm_mon=12, tm_mday=30, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=2, tm_yday=364, tm_isdst=-1), time.struct_time(tm_year=2027, tm_mon=1, tm_mday=14, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=14, tm_isdst=-1), time.struct_time(tm_year=2027, tm_mon=3, tm_mday=5, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=64, tm_isdst=-1), time.struct_time(tm_year=2027, tm_mon=5, tm_mday=19, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=2, tm_yday=139, tm_isdst=-1), time.struct_time(tm_year=2027, tm_mon=9, tm_mday=7, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=1, tm_yday=250, tm_isdst=-1), time.struct_time(tm_year=2027, tm_mon=11, tm_mday=12, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=316, tm_isdst=-1), time.struct_time(tm_year=2027, tm_mon=12, tm_mday=25, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=5, tm_yday=359, tm_isdst=-1), time.struct_time(tm_year=2028, tm_mon=2, tm_mday=2, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=2, tm_yday=33, tm_isdst=-1), time.struct_time(tm_year=2028, tm_mon=4, tm_mday=18, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=1, tm_yday=109, tm_isdst=-1), time.struct_time(tm_year=2028, tm_mon=7, tm_mday=31, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=0, tm_yday=213, tm_isdst=-1), time.struct_time(tm_year=2028, tm_mon=10, tm_mday=11, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=2, tm_yday=285, tm_isdst=-1), time.struct_time(tm_year=2028, tm_mon=12, tm_mday=20, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=2, tm_yday=355, tm_isdst=-1), time.struct_time(tm_year=2026, tm_mon=7, tm_mday=14, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=1, tm_yday=195, tm_isdst=-1), time.struct_time(tm_year=2026, tm_mon=9, tm_mday=5, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=5, tm_yday=248, tm_isdst=-1), time.struct_time(tm_year=2026, tm_mon=11, tm_mday=20, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=324, tm_isdst=-1), time.struct_time(tm_year=2027, tm_mon=1, tm_mday=12, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=1, tm_yday=12, tm_isdst=-1), time.struct_time(tm_year=2027, tm_mon=3, tm_mday=28, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=87, tm_isdst=-1), time.struct_time(tm_year=2027, tm_mon=6, tm_mday=15, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=1, tm_yday=166, tm_isdst=-1), time.struct_time(tm_year=2027, tm_mon=8, tm_mday=2, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=0, tm_yday=214, tm_isdst=-1), time.struct_time(tm_year=2027, tm_mon=10, tm_mday=31, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=304, tm_isdst=-1), time.struct_time(tm_year=2028, tm_mon=2, tm_mday=14, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=0, tm_yday=45, tm_isdst=-1), time.struct_time(tm_year=2028, tm_mon=5, tm_mday=22, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=0, tm_yday=143, tm_isdst=-1), time.struct_time(tm_year=2028, tm_mon=9, tm_mday=9, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=5, tm_yday=253, tm_isdst=-1), time.struct_time(tm_year=2028, tm_mon=12, tm_mday=25, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=0, tm_yday=360, tm_isdst=-1), time.struct_time(tm_year=2029, tm_mon=4, tm_mday=1, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=91, tm_isdst=-1), time.struct_time(tm_year=2029, tm_mon=7, tm_mday=19, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=200, tm_isdst=-1), time.struct_time(tm_year=2029, tm_mon=11, tm_mday=11, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=315, tm_isdst=-1)]
# 30
