# %% [markdown]
# ###O que é o Pandas e para que serve
#     - Análise de dados (seja para DataScience, seja para trabalhar de forma integrada com arquivos em Excel e Bancos de Dados)
#     - Melhor biblioteca/módulo para trabalhar com quantidades enormes de informações
#     - Uma mistura de listas e diconários de forma muito eficiente
#
# ###Resumo
#
# Se você trabalha com muitos dados, você vai precisar usar o pandas

# %%
#Forma de usar
import pandas as pd

# %% [markdown]
# ###Pandas e csv
#
# Quase sempre quando formos 'lê' um arquivo csv,vamos usar o pandas. É prático e bem eficiente
#
# ###Funcionamento
#
# Forma mais básica: (muitas vezes não usaremos a forma mais básica)
# dataframe = pd.read_csv('arquivo_com_extensão.csv')
#
#     - Vamos ler um arquivo real, com a Base de Dados de Vendas da Empresa 'Contoso'

# %%
df_vendas = pd.read_csv('Contoso - Cadastro Produtos.csv', sep=';')
df_vendas
# Out:
#                                       Nome do Produto  \
# 0               Contoso Wireless Laser Mouse E50 Grey
# 1       Contoso Optical Wheel OEM PS/2 Mouse E60 Grey
# 2      Contoso Optical Wheel OEM PS/2 Mouse E60 Black
# 3      Contoso Optical Wheel OEM PS/2 Mouse E60 White
# 4     Contoso Optical Wheel OEM PS/2 Mouse E60 Silver
# ...                                               ...
# 1685        SV DVD 12-Inch Player Portable M400 Black
# 1686        SV DVD 9-Inch Player Portable M300 Silver
# 1687       SV DVD 12-Inch Player Portable M400 Silver
# 1688         SV DVD 9-Inch Player Portable M300 White
# 1689        SV DVD 12-Inch Player Portable M400 White
#
#                                    Descricao do Produto        Fabricante  \
# 0     Advanced 2.4 GHz cordless technology makes fre...      Contoso, Ltd
# 1                        PS/2 mouse, 6 feet mouse cable      Contoso, Ltd
# 2                        PS/2 mouse, 6 feet mouse cable      Contoso, Ltd
# ...

# %%
df_vendas_2 = pd.read_csv('Contoso - Vendas - 2017.csv', sep=';')
df_vendas_2
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                     2    01/01/2017    06/01/2017         5      308
# 2                     3    01/01/2017    01/01/2017         0      294
# 3                     4    01/01/2017    01/01/2017         0      251
# 4                     5    01/01/2017    07/01/2017         6       94
# ...                 ...           ...           ...       ...      ...
# 980637           980638    31/12/2017    31/12/2017         0      194
# 980638           980639    31/12/2017    06/01/2018         6       32
# 980639           980640    31/12/2017    03/01/2018         3      210
# 980640           980641    31/12/2017    31/12/2017         0       53
# 980641           980642    31/12/2017    31/12/2017         0      309
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %% [markdown]
# ###DataFrame
#
# ####Resumo
#
# É como se fosse uma tabela
#
#     - As colunas funcionam 'como chaves de dicionário'
#     - As linhas funcionam 'como listas'
#
# ####Funcionamento
#
# Temos um dataframe chamado df_vendas
#
# - df_vendas['coluna_x'] -> uma lista com os valores da coluna_x (em formato dataframe, é um dataframe com 1 coluna só)
# - df_vendas[0] -> Não funciona assim para dataframe
# - df_vendas[:3] -> pega até a linha de índice 3 do odataframe
# - df_vendas[['coluna_X', 'coluna_y', 'coluna_z']] -> cria um novo dataframe com as colunas coluna_x, coluna_y e coluna_z
# - df_vendas['coluna_x'][0] -> pega o item da 1° linha da coluna coluna_x

# %%
df_vendas_2['ID Cliente']
# Out:
# 0          6825
# 1         18469
# 2         19730
# 3         29326
# 4         22617
#           ...
# 980637    10353
# 980638    31750
# 980639    12003
# 980640    25550
# 980641    28707
# Name: ID Cliente, Length: 980642, dtype: int64

# %%
df_vendas_2[:3]
# Out:
#    Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  ID Produto  \
# 0                1    01/01/2017    02/01/2017         1       86         981
# 1                2    01/01/2017    06/01/2017         5      308        1586
# 2                3    01/01/2017    01/01/2017         0      294        1444
#
#    ID Promocao  ID Cliente  Quantidade Vendida  Quantidade Devolvida
# 0            2        6825                   9                     1
# 1            2       18469                   9                     1
# 2            5       19730                  13                     1

# %%
df_vendas_2[['Numero da Venda', 'Data da Venda', 'ID Produto']]
# Out:
#         Numero da Venda Data da Venda  ID Produto
# 0                     1    01/01/2017         981
# 1                     2    01/01/2017        1586
# 2                     3    01/01/2017        1444
# 3                     4    01/01/2017        1468
# 4                     5    01/01/2017        1106
# ...                 ...           ...         ...
# 980637           980638    31/12/2017        2490
# 980638           980639    31/12/2017        2488
# 980639           980640    31/12/2017        2511
# 980640           980641    31/12/2017         436
# 980641           980642    31/12/2017        2510
#
# [980642 rows x 3 columns]

# %%
df_vendas_2['ID Produto'][0]
# Out:
# np.int64(981)

# %% [markdown]
# ###Aplicação
#
# - O 1° passo de toda a Análise de Dados é você entender o que existe na sua base de dados
#
# Usaremos o .info() para isso

# %%
df_vendas_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980642 entries, 0 to 980641
# Data columns (total 10 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Numero da Venda       980642 non-null  int64
#  1   Data da Venda         980642 non-null  object
#  2   Data do Envio         980642 non-null  object
#  3   ID Canal              980642 non-null  int64
#  4   ID Loja               980642 non-null  int64
#  5   ID Produto            980642 non-null  int64
#  6   ID Promocao           980642 non-null  int64
#  7   ID Cliente            980642 non-null  int64
#  8   Quantidade Vendida    980642 non-null  int64
#  9   Quantidade Devolvida  980642 non-null  int64
# dtypes: int64(8), object(2)
# memory usage: 74.8+ MB

# %%
lista_clientes = df_vendas_2['ID Cliente']
lista_clientes
# Out:
# 0          6825
# 1         18469
# 2         19730
# 3         29326
# 4         22617
#           ...
# 980637    10353
# 980638    31750
# 980639    12003
# 980640    25550
# 980641    28707
# Name: ID Cliente, Length: 980642, dtype: int64

# %%
produtos_quantidades = df_vendas_2[['ID Produto', 'Quantidade Vendida', 'Quantidade Devolvida']]
produtos_quantidades
# Out:
#         ID Produto  Quantidade Vendida  Quantidade Devolvida
# 0              981                   9                     1
# 1             1586                   9                     1
# 2             1444                  13                     1
# 3             1468                   6                     1
# 4             1106                   4                     1
# ...            ...                 ...                   ...
# 980637        2490                 120                     0
# 980638        2488                 120                     0
# 980639        2511                  80                     0
# 980640         436                  39                     0
# 980641        2510                  80                     0
#
# [980642 rows x 3 columns]

# %% [markdown]
# ###Comparando, tratando e mesclando dataframes
#
# ####Objetivo
#
# Vamos modificar od IDs para os nomes dos produtos, dos clientes e das lojas, para nossas análises ficarem mais intuitivas futuramente. Para isso, vamos criar um dataframe com todos os detalhes
#
# - Usaremos o método merge para isso e, depois se quisermos,podemos pegar apenas as colunas que queremos do dataframe final

# %%
df_vendas_2
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                     2    01/01/2017    06/01/2017         5      308
# 2                     3    01/01/2017    01/01/2017         0      294
# 3                     4    01/01/2017    01/01/2017         0      251
# 4                     5    01/01/2017    07/01/2017         6       94
# ...                 ...           ...           ...       ...      ...
# 980637           980638    31/12/2017    31/12/2017         0      194
# 980638           980639    31/12/2017    06/01/2018         6       32
# 980639           980640    31/12/2017    03/01/2018         3      210
# 980640           980641    31/12/2017    31/12/2017         0       53
# 980641           980642    31/12/2017    31/12/2017         0      309
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
df_produtos = pd.read_csv('Contoso - Cadastro Produtos.csv', sep=';')
display(df_produtos)
# Out:
#                                       Nome do Produto  \
# 0               Contoso Wireless Laser Mouse E50 Grey
# 1       Contoso Optical Wheel OEM PS/2 Mouse E60 Grey
# 2      Contoso Optical Wheel OEM PS/2 Mouse E60 Black
# 3      Contoso Optical Wheel OEM PS/2 Mouse E60 White
# 4     Contoso Optical Wheel OEM PS/2 Mouse E60 Silver
# ...                                               ...
# 1685        SV DVD 12-Inch Player Portable M400 Black
# 1686        SV DVD 9-Inch Player Portable M300 Silver
# 1687       SV DVD 12-Inch Player Portable M400 Silver
# 1688         SV DVD 9-Inch Player Portable M300 White
# 1689        SV DVD 12-Inch Player Portable M400 White
#
#                                    Descricao do Produto        Fabricante  \
# 0     Advanced 2.4 GHz cordless technology makes fre...      Contoso, Ltd
# 1                        PS/2 mouse, 6 feet mouse cable      Contoso, Ltd
# 2                        PS/2 mouse, 6 feet mouse cable      Contoso, Ltd
# ...

# %%
df_lojas = pd.read_csv('Contoso - Lojas.csv', sep=';')
display(df_lojas)
# Out:
#      ID Loja                         Nome da Loja  Quantidade Colaboradores  \
# 0          1           Loja Contoso Seattle No.1                       17.0
# 1          2           Loja Contoso Seattle No.2                       25.0
# 2          3              Loja Contoso Kennewick                       26.0
# 3          4               Loja Contoso Bellevue                       19.0
# 4          5                Loja Contoso Redmond                       33.0
# ..       ...                                  ...                       ...
# 301      306          Loja Contoso Europe Online                        7.0
# 302      307            Loja Contoso Asia Online                        8.0
# 303      308  Loja Contoso North America Reseller                      15.0
# 304      309         Loja Contoso Europe Reseller                      12.0
# 305      310           Loja Contoso Asia Reseller                      17.0
#
#                País
# 0    Estados Unidos
# ...

# %%
df_clientes = pd.read_csv('Contoso - Clientes.csv', sep=';')
display(df_clientes)
# Out:
#        ID Cliente Primeiro Nome     Sobrenome                         E-mail  \
# 0               1        Garnet    Lanfranchi    glanfranchi0@mayoclinic.com
# 1               2       Lurette     Roseblade      lroseblade1@bigcartel.com
# 2               3       Glenden     Ishchenko      gishchenko2@moonfruit.com
# 3               4         Baron  Jedrzejewsky    bjedrzejewsky3@e-recht24.de
# 4               5        Sheree      Bredbury       sbredbury4@sitemeter.com
# ...           ...           ...           ...                            ...
# 39499       39500        Brandy      Malhotra    brandy0@adventure-works.com
# 39500       39501        Alicia          Raje   alicia12@adventure-works.com
# 39501       39502        Connie           Rai    connie4@adventure-works.com
# 39502       39503         Shawn          Raji    shawn23@adventure-works.com
# 39503       39504       Lindsey        Sharma  lindsey10@adventure-works.com
#
# ...

# %%
#Vamos tirar as colunas inúteis do df_clientes ou pegar apenas as colunas que quisermos

#.drop(['coluna_1','coluna_2', 'coluna_3']) -> retira as colunas: coluna_1, coluna_2, coluna_3

df_cliente = df_clientes.drop(['Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10'], axis=1)
display(df_cliente)
# Out:
#        ID Cliente Primeiro Nome     Sobrenome                         E-mail  \
# 0               1        Garnet    Lanfranchi    glanfranchi0@mayoclinic.com
# 1               2       Lurette     Roseblade      lroseblade1@bigcartel.com
# 2               3       Glenden     Ishchenko      gishchenko2@moonfruit.com
# 3               4         Baron  Jedrzejewsky    bjedrzejewsky3@e-recht24.de
# 4               5        Sheree      Bredbury       sbredbury4@sitemeter.com
# ...           ...           ...           ...                            ...
# 39499       39500        Brandy      Malhotra    brandy0@adventure-works.com
# 39500       39501        Alicia          Raje   alicia12@adventure-works.com
# 39501       39502        Connie           Rai    connie4@adventure-works.com
# 39502       39503         Shawn          Raji    shawn23@adventure-works.com
# 39503       39504       Lindsey        Sharma  lindsey10@adventure-works.com
#
# ...

# %%
df_produto = df_produtos[['Nome do Produto', 'ID Produto']]
display(df_produto)
# Out:
#                                       Nome do Produto  ID Produto
# 0               Contoso Wireless Laser Mouse E50 Grey         873
# 1       Contoso Optical Wheel OEM PS/2 Mouse E60 Grey         879
# 2      Contoso Optical Wheel OEM PS/2 Mouse E60 Black         880
# 3      Contoso Optical Wheel OEM PS/2 Mouse E60 White         881
# 4     Contoso Optical Wheel OEM PS/2 Mouse E60 Silver         882
# ...                                               ...         ...
# 1685        SV DVD 12-Inch Player Portable M400 Black        1602
# 1686        SV DVD 9-Inch Player Portable M300 Silver        1606
# 1687       SV DVD 12-Inch Player Portable M400 Silver        1607
# 1688         SV DVD 9-Inch Player Portable M300 White        1611
# 1689        SV DVD 12-Inch Player Portable M400 White        1612
#
# [1690 rows x 2 columns]

# %%
df_loja = df_lojas[['ID Loja', 'Nome da Loja']]
display(df_loja)
# Out:
#      ID Loja                         Nome da Loja
# 0          1           Loja Contoso Seattle No.1
# 1          2           Loja Contoso Seattle No.2
# 2          3              Loja Contoso Kennewick
# 3          4               Loja Contoso Bellevue
# 4          5                Loja Contoso Redmond
# ..       ...                                  ...
# 301      306          Loja Contoso Europe Online
# 302      307            Loja Contoso Asia Online
# 303      308  Loja Contoso North America Reseller
# 304      309         Loja Contoso Europe Reseller
# 305      310           Loja Contoso Asia Reseller
#
# [306 rows x 2 columns]

# %%
#Agora vamos juntar os dataframes para ter 1 único dataframe com tudo 'bonito'

#novo_dataframe = dataframe1.merge(dataframe2, on='coluna')
#OBS: O merge precisa das colunas com o mesmo nome para funcionar. Se não tiver, você precisa alterar o nome da coluna com o .rename

vendas_df = df_vendas_2.merge(df_produto, on='ID Produto')
vendas_df = vendas_df.merge(df_loja, on='ID Loja')
vendas_df = vendas_df.merge(df_cliente, on='ID Cliente')
vendas_df.head()
# Out:
#    Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  ID Produto  \
# 0                1    01/01/2017    02/01/2017         1       86         981
# 1                2    01/01/2017    06/01/2017         5      308        1586
# 2                3    01/01/2017    01/01/2017         0      294        1444
# 3                4    01/01/2017    01/01/2017         0      251        1468
# 4                5    01/01/2017    07/01/2017         6       94        1106
#
#    ID Promocao  ID Cliente  Quantidade Vendida  Quantidade Devolvida  \
# 0            2        6825                   9                     1
# 1            2       18469                   9                     1
# 2            5       19730                  13                     1
# 3            5       29326                   6                     1
# 4            2       22617                   4                     1
#
#                                      Nome do Produto  \
# ...

# %%
#dataframe.rename({'coluna1':'novo_coluna1'})
vendas_df = vendas_df.rename({'E-mail':'E-mail do Cliente'}, )
vendas_df.head()
# Out:
#    Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  ID Produto  \
# 0                1    01/01/2017    02/01/2017         1       86         981
# 1                2    01/01/2017    06/01/2017         5      308        1586
# 2                3    01/01/2017    01/01/2017         0      294        1444
# 3                4    01/01/2017    01/01/2017         0      251        1468
# 4                5    01/01/2017    07/01/2017         6       94        1106
#
#    ID Promocao  ID Cliente  Quantidade Vendida  Quantidade Devolvida  \
# 0            2        6825                   9                     1
# 1            2       18469                   9                     1
# 2            5       19730                  13                     1
# 3            5       29326                   6                     1
# 4            2       22617                   4                     1
#
#                                      Nome do Produto  \
# ...

# %% [markdown]
# ####Qual cliente que comprou mais vezes?
#
# - Usaremos o método .value_counts() para contar quantas vezes cada valor do DataFrame aparece
# - Usaremos o método .plot() para exibir um gráfico

# %%
freq_clinetes = vendas_df['E-mail'].value_counts()
freq_clinetes
# Out:
# E-mail
# karen33@adventure-works.com      77
# chloe77@adventure-works.com      74
# julia43@adventure-works.com      69
# gilbert9@adventure-works.com     68
# destiny66@adventure-works.com    68
#                                  ..
# mblemen9o@ebay.com                1
# rebecca15@adventure-works.com     1
# kevin10@adventure-works.com       1
# siliffe8l@spotify.com             1
# clifford8@adventure-works.com     1
# Name: count, Length: 38907, dtype: int64

# %%
freq_clinetes[:5].plot(figsize=(15,5))
# Out:
# <Axes: xlabel='E-mail'>

# %% [markdown]
# ####Qual loja mais vendeu?
#
# - Usaremos o .groupby para agrupar o nosso dataframe,de acordo com o que queremos (somando as quantidades de vendas, por exemplo)

# %%
vendas_lojas = vendas_df.groupby('Nome da Loja').sum()
vendas_lojas = vendas_lojas[['Quantidade Vendida']]
vendas_lojas
# Out:
#                           Quantidade Vendida
# Nome da Loja
# Loja Contoso Albany                    26353
# Loja Contoso Alexandria                26247
# Loja Contoso Amsterdam                 28294
# Loja Contoso Anchorage                 27451
# Loja Contoso Annapolis                 26065
# ...                                      ...
# Loja Contoso Yokohama                  28023
# Loja Contoso York                      27164
# Loja Contoso koln No.1                 29046
# Loja Contoso koln No.2                 29650
# Loja Contoso obamberg                  29336
#
# [306 rows x 1 columns]

# %% [raw]
# Agora precisamos pegar o maior valor. Temos 2 formas:
#     - Ordenar o dataframe em ordem decrescente de quantidade de vendas
#         - método .sort_values
#
#     - Pegar o Maior valor diretamente
#         - método .max() e idxmax()

# %%
vendas_lojas = vendas_lojas.sort_values('Quantidade Vendida', ascending=False)
vendas_lojas
# Out:
#                                      Quantidade Vendida
# Nome da Loja
# Loja Contoso Catalog                            1029117
# Loja Contoso North America Online                701961
# Loja Contoso Europe Online                       616845
# Loja Contoso Asia Online                         578458
# Loja Contoso North America Reseller              520176
# ...                                                 ...
# Loja Contoso Berlin                                 379
# Loja Contoso Paterson                               371
# Loja Contoso Marseille                              370
# Loja Contoso Racine No.2                            253
# Loja Contoso Venezia                                234
#
# [306 rows x 1 columns]

# %%
vendas_lojas[:5].plot(figsize=(15,5))
# Out:
# <Axes: xlabel='Nome da Loja'>

# %%
vendas_lojas[:5].plot(figsize=(15,5), kind='bar')
# Out:
# <Axes: xlabel='Nome da Loja'>

# %%
maior_valor = vendas_lojas['Quantidade Vendida'].max()
melhor_loja = vendas_lojas['Quantidade Vendida'].idxmax()

# %%
maior_valor
# Out:
# 1029117

# %%
melhor_loja
# Out:
# 'Loja Contoso Catalog '

# %%
menor_valor = vendas_lojas['Quantidade Vendida'].min()
menor_valor
# Out:
# 234

# %%
pior_loja = vendas_lojas['Quantidade Vendida'].idxmin()
pior_loja
# Out:
# 'Loja Contoso Venezia '

# %% [markdown]
# ###Filtrando informações nos dataframes
#
# ####Resumo

# %% [raw]
# Um dos grandes potenciais do pandas é para tratar condições
#
# É a forma com que analisamos condições no dataframe é diferente do que já fizemos até agorano curso, vamos ver como funciona
#
#     -> Preparando as bases de dados

# %%
vendas_df.head()
# Out:
#    Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  ID Produto  \
# 0                1    01/01/2017    02/01/2017         1       86         981
# 1                2    01/01/2017    06/01/2017         5      308        1586
# 2                3    01/01/2017    01/01/2017         0      294        1444
# 3                4    01/01/2017    01/01/2017         0      251        1468
# 4                5    01/01/2017    07/01/2017         6       94        1106
#
#    ID Promocao  ID Cliente  Quantidade Vendida  Quantidade Devolvida  \
# 0            2        6825                   9                     1
# 1            2       18469                   9                     1
# 2            5       19730                  13                     1
# 3            5       29326                   6                     1
# 4            2       22617                   4                     1
#
#                                      Nome do Produto  \
# ...

# %%
df_produtos.head()
# Out:
#                                    Nome do Produto  \
# 0            Contoso Wireless Laser Mouse E50 Grey
# 1    Contoso Optical Wheel OEM PS/2 Mouse E60 Grey
# 2   Contoso Optical Wheel OEM PS/2 Mouse E60 Black
# 3   Contoso Optical Wheel OEM PS/2 Mouse E60 White
# 4  Contoso Optical Wheel OEM PS/2 Mouse E60 Silver
#
#                                 Descricao do Produto    Fabricante  \
# 0  Advanced 2.4 GHz cordless technology makes fre...  Contoso, Ltd
# 1                     PS/2 mouse, 6 feet mouse cable  Contoso, Ltd
# 2                     PS/2 mouse, 6 feet mouse cable  Contoso, Ltd
# 3                     PS/2 mouse, 6 feet mouse cable  Contoso, Ltd
# 4                     PS/2 mouse, 6 feet mouse cable  Contoso, Ltd
#
#   Nome da Marca       Tipo Custo Unitario Preco Unitario  ID Produto  \
# 0       Contoso  Econômico          10,69          20,96         873
# 1       Contoso  Econômico           6,63             13         879
# ...

# %%
df_lojas.head()
# Out:
#    ID Loja                Nome da Loja  Quantidade Colaboradores  \
# 0        1  Loja Contoso Seattle No.1                       17.0
# 1        2  Loja Contoso Seattle No.2                       25.0
# 2        3     Loja Contoso Kennewick                       26.0
# 3        4      Loja Contoso Bellevue                       19.0
# 4        5       Loja Contoso Redmond                       33.0
#
#              País
# 0  Estados Unidos
# 1  Estados Unidos
# 2  Estados Unidos
# 3  Estados Unidos
# 4  Estados Unidos

# %%
df_cliente.head()
# Out:
#    ID Cliente Primeiro Nome     Sobrenome                       E-mail  \
# 0           1        Garnet    Lanfranchi  glanfranchi0@mayoclinic.com
# 1           2       Lurette     Roseblade    lroseblade1@bigcartel.com
# 2           3       Glenden     Ishchenko    gishchenko2@moonfruit.com
# 3           4         Baron  Jedrzejewsky  bjedrzejewsky3@e-recht24.de
# 4           5        Sheree      Bredbury     sbredbury4@sitemeter.com
#
#       Genero  Numero de Filhos Data de Nascimento
# 0   Feminino                 2         12/05/1995
# 1   Feminino                 2         30/06/1943
# 2  Masculino                 5         09/04/1989
# 3  Masculino                 4         17/11/1998
# 4   Feminino                 5         08/09/1975

# %%
#limpando apenas as colunas que queremos
df_cliente = df_cliente[['ID Cliente', 'E-mail']]
df_produtos = df_produtos[['ID Produto', 'Nome do Produto']]
df_lojas = df_lojas[['ID Loja', 'Nome da Loja']]

# %%
#Mesclando e renomeando os dataframes
vendas_df = vendas_df.merge(df_produtos, on='ID Produto')
vendas_df = vendas_df.merge(df_lojas, on = 'ID Loja')
vendas_df = vendas_df.merge(df_clientes, on='ID Cliente').rename(columns={'E-mail': 'E-mail do cliente'})

# %% [markdown]
# ####Primeiro, vamos aplicar uma função normalmente. Qual o % das vendas que foi devolvido?
#
# * Para isso vamos somar as quantidades nas colunas correspondentes. Lembrando, o % vai ser: Total Devolvido / Total vendido

# %%
qtde_vendida = vendas_df['Quantidade Vendida'].sum()
qtde_devolvida = vendas_df['Quantidade Devolvida'].sum()
print(f'{qtde_devolvida / qtde_vendida:.2%}')
# Out:
# 1.17%

# %% [markdown]
# ####Agora, se qusiermos fazer a mesma análise apenas para 1 loja. Queremos filtrar apenas os itens da Loja C Europe Online e saber o % de devolução dessa loja
#
# * Para isso, vamos precisar filtrar. A forma de filtrar nos dataframes é uma 'simples' comparação

# %%
vendas_loja_contoso = vendas_df[vendas_df['ID Loja'] == 306]
qtde_vendida = vendas_loja_contoso['Quantidade Vendida'].sum()
qtde_devolvida = vendas_loja_contoso['Quantidade Devolvida'].sum()
print(f'{qtde_devolvida / qtde_vendida:.2%}')
# Out:
# 1.33%

# %% [markdown]
# Desafio: e se eu quisesse criar uma tabela apenas com as vendas da Loja Contoso Europe Online e que não tiveram nenhuma devolução. Quero criar essa tabela e saber quantas vendas são

# %%
vendas_ID_loja = vendas_df[vendas_df['ID Loja'] == 306]
vendas_sem_devolucao = vendas_ID_loja[vendas_ID_loja['Quantidade Devolvida'] == 0]
vendas_sem_devolucao.head()
#df_loja306_sdevolucao = vendas_df[(vendas_df['ID Loja] == 306) & (vendas_df['Quantidade Devolvida] == 0)]
# Out:
#      Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 98                99    01/01/2017    03/01/2017         2      306
# 165              166    01/01/2017    02/01/2017         1      306
# 166              167    01/01/2017    05/01/2017         4      306
# 186              187    01/01/2017    06/01/2017         5      306
# 198              199    01/01/2017    03/01/2017         2      306
#
#      ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# 98         1269           10       26238                   8
# 165        1107           10        7242                  16
# 166         242           10       34277                  16
# 186        1479           10       23132                   8
# 198         819           10        5363                   4
#
#      Quantidade Devolvida  ... Primeiro Nome_y Sobrenome_y  \
# 98                      0  ...          Edward    Phillips
# 165                     0  ...         Kellina     Hanhard
# ...

# %% [markdown]
# ###Adicionando colunas, modificando colunas e valores

# %%
vendas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980642 entries, 0 to 980641
# Data columns (total 30 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Numero da Venda       980642 non-null  int64
#  1   Data da Venda         980642 non-null  object
#  2   Data do Envio         980642 non-null  object
#  3   ID Canal              980642 non-null  int64
#  4   ID Loja               980642 non-null  int64
#  5   ID Produto            980642 non-null  int64
#  6   ID Promocao           980642 non-null  int64
#  7   ID Cliente            980642 non-null  int64
#  8   Quantidade Vendida    980642 non-null  int64
#  9   Quantidade Devolvida  980642 non-null  int64
#  10  Nome do Produto_x     980642 non-null  object
#  11  Nome da Loja_x        980642 non-null  object
#  12  Primeiro Nome_x       980642 non-null  object
#  13  Sobrenome_x           980642 non-null  object
# ...

# %% [markdown]
# Agora, e se quisermos acrescetar uma coluna com o mês, o dia e o ano de cada venda (e não só a data completa)

# %%
vendas_df['Data da Venda'] = pd.to_datetime(vendas_df['Data da Venda'], format='%d/%m/%Y')
vendas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980642 entries, 0 to 980641
# Data columns (total 30 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Numero da Venda       980642 non-null  int64
#  1   Data da Venda         980642 non-null  datetime64[ns]
#  2   Data do Envio         980642 non-null  object
#  3   ID Canal              980642 non-null  int64
#  4   ID Loja               980642 non-null  int64
#  5   ID Produto            980642 non-null  int64
#  6   ID Promocao           980642 non-null  int64
#  7   ID Cliente            980642 non-null  int64
#  8   Quantidade Vendida    980642 non-null  int64
#  9   Quantidade Devolvida  980642 non-null  int64
#  10  Nome do Produto_x     980642 non-null  object
#  11  Nome da Loja_x        980642 non-null  object
#  12  Primeiro Nome_x       980642 non-null  object
#  13  Sobrenome_x           980642 non-null  object
# ...

# %%
vendas_df['Ano da Venda'] = vendas_df['Data da Venda'].dt.year
vendas_df['Mes da Venda'] = vendas_df['Data da Venda'].dt.month
vendas_df['Dia da Venda'] = vendas_df['Data da Venda'].dt.day
vendas_df.head(3)
# Out:
#    Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  ID Produto  \
# 0                1    2017-01-01    02/01/2017         1       86         981
# 1                2    2017-01-01    06/01/2017         5      308        1586
# 2                3    2017-01-01    01/01/2017         0      294        1444
#
#    ID Promocao  ID Cliente  Quantidade Vendida  Quantidade Devolvida  ...  \
# 0            2        6825                   9                     1  ...
# 1            2       18469                   9                     1  ...
# 2            5       19730                  13                     1  ...
#
#     Genero_y Numero de Filhos_y Data de Nascimento_y Unnamed: 7 Unnamed: 8  \
# 0  Masculino                  4           02/01/1979        NaN        NaN
# 1   Feminino                  5           09/02/1961        NaN        NaN
# 2  Masculino                  2           30/12/1958        NaN        NaN
#
# ...

# %%
vendas_df = vendas_df.drop(['Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10'], axis=1)
vendas_df.head(3)
# Out:
#    Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  ID Produto  \
# 0                1    2017-01-01    02/01/2017         1       86         981
# 1                2    2017-01-01    06/01/2017         5      308        1586
# 2                3    2017-01-01    01/01/2017         0      294        1444
#
#    ID Promocao  ID Cliente  Quantidade Vendida  Quantidade Devolvida  ...  \
# 0            2        6825                   9                     1  ...
# 1            2       18469                   9                     1  ...
# 2            5       19730                  13                     1  ...
#
#                         Nome da Loja_y Primeiro Nome_y Sobrenome_y  \
# 0                 Loja Contoso Austin            Rurik   Brumfield
# 1  Loja Contoso North America Reseller        Cornelle        Shaw
# 2            Loja Contoso Tehran No.2           Kermit      Gorrie
#
#                  E-mail_y   Genero_y Numero de Filhos_y  Data de Nascimento_y  \
# ...

# %% [markdown]
# ###Antes de entrar no próximo exemplo, precisamos falar de 2 métodos:
#
# 1 - `.loc`- permite pegar uma linha de acordo com o índice dela. Ele dá erro caso não encontre o índice. Isso é interessante principalmente quando o índice é uma informação relevante ao invés só do número do índice ou quando queremos pegar alguma linha específica do dataframe (ao invés de ir do começo do dataframe até a linha 5,por exemplo).
#
# Também podemos usar como loc[índice_linha, índice_coluna] para acessar um valor específico e modificá-lo
#
# 2 - `.iloc` - enxega o dataframe como linhas e colunas e consegue pegar o valor com um número de linha e um númeor de coluna. Repara que ele não analisa o valor do índice da linha e da coluna, apenas posição importa.
#
# uso: .iloc[num_linha, num_coluna]

# %%
df_produtos = pd.read_csv('Contoso - Cadastro Produtos.csv', sep=';')
novo_produto_df = df_produtos.set_index('Nome do Produto')
novo_produto_df
# Out:
#                                                                               Descricao do Produto  \
# Nome do Produto
# Contoso Wireless Laser Mouse E50 Grey            Advanced 2.4 GHz cordless technology makes fre...
# Contoso Optical Wheel OEM PS/2 Mouse E60 Grey                       PS/2 mouse, 6 feet mouse cable
# Contoso Optical Wheel OEM PS/2 Mouse E60 Black                      PS/2 mouse, 6 feet mouse cable
# Contoso Optical Wheel OEM PS/2 Mouse E60 White                      PS/2 mouse, 6 feet mouse cable
# Contoso Optical Wheel OEM PS/2 Mouse E60 Silver                     PS/2 mouse, 6 feet mouse cable
# ...                                                                                            ...
# SV DVD 12-Inch Player Portable M400 Black        6-hour rechargeable battery, 180-degree swivel...
# SV DVD 9-Inch Player Portable M300 Silver        6-hour rechargeable battery, 180-degree swivel...
# ...

# %%
df_produtos.loc[[0,2,5]]
# Out:
#                                   Nome do Produto  \
# 0           Contoso Wireless Laser Mouse E50 Grey
# 2  Contoso Optical Wheel OEM PS/2 Mouse E60 Black
# 5      Contoso Bluetooth Notebook Mouse E70 Black
#
#                                 Descricao do Produto    Fabricante  \
# 0  Advanced 2.4 GHz cordless technology makes fre...  Contoso, Ltd
# 2                     PS/2 mouse, 6 feet mouse cable  Contoso, Ltd
# 5  Transceiver-free wireless connection to your P...  Contoso, Ltd
#
#   Nome da Marca       Tipo Custo Unitario Preco Unitario  ID Produto  \
# 0       Contoso  Econômico          10,69          20,96         873
# 2       Contoso  Econômico           6,63             13         880
# 5       Contoso  Econômico          25,49             50         887
#
#    ID Subcategoria
# 0               22
# 2               22
# 5               22

# %%
novo_produto_df.loc['Contoso Optical Wheel OEM PS/2 Mouse E60 White', 'Preco Unitario']
# Out:
# '13'

# %%
novo_produto_df.iloc[2, 5]
# Out:
# '13'

# %% [markdown]
# A empresa decidiu aumentar o preço do produto ID 873 (Contoso Wireless Laser Mouse E50 Grey) para 2. Como fazemos, para modificar isso na nossa base?

# %%
novo_produto_df.loc['Contoso Wireless Laser Mouse E50 Grey', 'Preco Unitario'] = 23
novo_produto_df.head(3)
# Out:
#                                                                              Descricao do Produto  \
# Nome do Produto
# Contoso Wireless Laser Mouse E50 Grey           Advanced 2.4 GHz cordless technology makes fre...
# Contoso Optical Wheel OEM PS/2 Mouse E60 Grey                      PS/2 mouse, 6 feet mouse cable
# Contoso Optical Wheel OEM PS/2 Mouse E60 Black                     PS/2 mouse, 6 feet mouse cable
#
#                                                   Fabricante Nome da Marca  \
# Nome do Produto
# Contoso Wireless Laser Mouse E50 Grey           Contoso, Ltd       Contoso
# Contoso Optical Wheel OEM PS/2 Mouse E60 Grey   Contoso, Ltd       Contoso
# Contoso Optical Wheel OEM PS/2 Mouse E60 Black  Contoso, Ltd       Contoso
#
#                                                      Tipo Custo Unitario  \
# Nome do Produto
# Contoso Wireless Laser Mouse E50 Grey           Econômico          10,69
# Contoso Optical Wheel OEM PS/2 Mouse E60 Grey   Econômico           6,63
# ...

# %%
df_produtos.loc[df_produtos['ID Produto'] == 873, 'Preco Unitario'] = 23
df_produtos.head(3)
# Out:
#                                   Nome do Produto  \
# 0           Contoso Wireless Laser Mouse E50 Grey
# 1   Contoso Optical Wheel OEM PS/2 Mouse E60 Grey
# 2  Contoso Optical Wheel OEM PS/2 Mouse E60 Black
#
#                                 Descricao do Produto    Fabricante  \
# 0  Advanced 2.4 GHz cordless technology makes fre...  Contoso, Ltd
# 1                     PS/2 mouse, 6 feet mouse cable  Contoso, Ltd
# 2                     PS/2 mouse, 6 feet mouse cable  Contoso, Ltd
#
#   Nome da Marca       Tipo Custo Unitario Preco Unitario  ID Produto  \
# 0       Contoso  Econômico          10,69             23         873
# 1       Contoso  Econômico           6,63             13         879
# 2       Contoso  Econômico           6,63             13         880
#
#    ID Subcategoria
# 0               22
# 1               22
# 2               22

# %% [markdown]
# ###Exportando do DataFrame para um csv
#
# Depois de modificar um Dataframe, ou até criar um, muitas vezes podemos exportar esse dataframe para um csv
#
# No pandas, isso ébem simples:
#
# dataframe.to_csv('nome_do_arquivo.csv', sep=',')

# %%
vendas_df.to_csv('Novo Vendas 2017.csv', sep=';', encoding='latin1')

# %% [markdown]
# ###Pandas lendo csv da internet
#
# 2 situações principais em que você consegue fazer direto
#
# 1. Arquivo csv direto no link (melhor dos mundos)
#
# 2. O arquivo csv é gerado para você, mas fica no meio de uma requisição que precisa ser tratada

# %%
#Caso 1: csv direto do link
url = 'https://drive.google.com/uc?authuser=0&id=1Ru7s-x3YJuStZK1mqr_qNqiHVvdHUN66&export=download'
cotacao_df = pd.read_csv(url)
display(cotacao_df)
# Out:
#               Date   Price    Open    High     Low Change %
# 0     Jan 01, 2020  4.0195  4.0195  4.0195  4.0195    0.00%
# 1     Dec 31, 2019  4.0195  4.0201  4.0201  4.0195    0.00%
# 2     Dec 30, 2019  4.0195  4.0484  4.0484  4.0084   -0.65%
# 3     Dec 27, 2019  4.0460  4.0568  4.0614  4.0339   -0.25%
# 4     Dec 26, 2019  4.0560  4.0827  4.0827  4.0453   -0.68%
# ...            ...     ...     ...     ...     ...      ...
# 3908  Jan 07, 2005  2.7120  2.7230  2.7290  2.6890   -0.36%
# 3909  Jan 06, 2005  2.7218  2.7140  2.7340  2.7060    0.27%
# 3910  Jan 05, 2005  2.7145  2.6980  2.7331  2.6910   -0.17%
# 3911  Jan 04, 2005  2.7190  2.6720  2.7230  2.6720    1.61%
# 3912  Jan 03, 2005  2.6759  2.6610  2.6760  2.6520    0.75%
#
# [3913 rows x 6 columns]

# %%
#Caso 2: csv em uma requisição que precisa ser tratada
import requests
import io

url = 'https://portalweb.cooxupe.com.br:9080/portal/precohistoricocafe_2.jsp;jsessionid=F02909BBEFCFA180E303E017A95A6249?d-3496238-e=2&6578706f7274=1'
conteudo_url = requests.get(url).content
arquivo = io.StringIO(conteudo_url.decode('latin1'))
cafe_df = pd.read_csv(arquivo, sep=r'\t', engine='python')
cafe_df.head(3)
# Out:
#     "Ano"  "Janeiro" "Fevereiro"    "Março"    "Abril"     "Maio"    "Junho"  \
# 0  "2025"  "2256.79"    "2564.1"  "2554.43"  "2564.42"  "2382.57"  "2152.81"
# 1  "2024"   "974.46"   "1005.54"  "1023.45"  "1145.12"  "1186.17"  "1240.85"
# 2  "2023"  "1030.14"   "1130.26"  "1103.37"  "1115.24"  "1030.64"   "927.88"
#
#      "Julho"   "Agosto" "Setembro"  "Outubro" "Novembro" "Dezembro"
# 0         ""         ""         ""         ""         ""         ""
# 1  "1216.35"  "1279.77"  "1316.36"  "1463.25"  "1732.67"  "2063.69"
# 2    "878.5"   "868.24"   "802.59"   "800.95"    "845.6"   "925.46"
